# %% [markdown]
# Multiplicacion de matrices con umpy

# %%
import time
import matplotlib.pyplot as pl
import numpy as num
n=25

a=[]
b=[]
t=0
t1=0
for x in range(1,n+1):
    a.append((x))
    c=num.full((x,x),1)
    d=num.full((x,x),2)
    e=num.full((x,x),0)
    for y in range(x):
        tt=time.clock()
        e=c.dot(d)
        t=t+time.clock()-tt
        t1=t1+1
    t=t/t1
    b.append(t)


pl.xlabel("Tamano de la matriz")
pl.ylabel("Tiempo")
pl.title("Timpo estimado")
pl.plot(a,b)
pl.show()

for x in range(len(b)):
    print "Tiempo para n="+str(x+1)+": " + str(b[x])
# Out:
# Tiempo para n=1: 2.19999999995e-05
# Tiempo para n=2: 2.13333333334e-05
# Tiempo para n=3: 9.05555555608e-06
# Tiempo para n=4: 5.20555555603e-06
# Tiempo para n=5: 3.88037037027e-06
# Tiempo para n=6: 3.18477954129e-06
# Tiempo para n=7: 2.68517069785e-06
# Tiempo para n=8: 2.38014363078e-06
# Tiempo para n=9: 2.25289208081e-06
# Tiempo para n=10: 2.04096167425e-06
# Tiempo para n=11: 1.86425699497e-06
# Tiempo para n=12: 1.74184944859e-06
# Tiempo para n=13: 1.86529504887e-06
# Tiempo para n=14: 1.54157423856e-06
# Tiempo para n=15: 1.47951311866e-06
# Tiempo para n=16: 1.85646700821e-06
# Tiempo para n=17: 1.45004226803e-06
# Tiempo para n=18: 1.39444469161e-06
# Tiempo para n=19: 1.38628655101e-06
# Tiempo para n=20: 1.20183945977e-06
# Tiempo para n=21: 1.18702095006e-06
# Tiempo para n=22: 1.93354553737e-06
# Tiempo para n=23: 1.16642588963e-06
# Tiempo para n=24: 1.10722141963e-06
# Tiempo para n=25: 1.09879145052e-06

# %% [markdown]
# Y en ideone.com:
# Tiempo para n=1: 1.3e-05
# Tiempo para n=2: 6.00000000001e-06
# Tiempo para n=3: 1.66666666666e-06
# Tiempo para n=4: 1.06666666666e-06
# Tiempo para n=5: 8.04444444447e-07
# Tiempo para n=6: 5.14497354493e-07
# Tiempo para n=7: 5.54089191234e-07
# Tiempo para n=8: 4.87613588647e-07
# Tiempo para n=9: 4.77502524193e-07
# Tiempo para n=10: 4.81409136804e-07
# Tiempo para n=11: 5.07294077831e-07
# Tiempo para n=12: 5.06503770227e-07
# Tiempo para n=13: 8.29741799673e-07
# Tiempo para n=14: 5.50759445711e-07
# Tiempo para n=15: 5.71256328713e-07
# Tiempo para n=16: 6.1449453183e-07
# Tiempo para n=17: 6.51075127659e-07
# Tiempo para n=18: 6.7632207677e-07
# Tiempo para n=19: 7.45664853037e-07
# Tiempo para n=20: 7.79741261205e-07
# Tiempo para n=21: 8.43202343122e-07
# Tiempo para n=22: 8.92660878826e-07
# Tiempo para n=23: 9.70625582894e-07
# Tiempo para n=24: 1.00656875194e-06
# Tiempo para n=25: 1.07078944231e-06
