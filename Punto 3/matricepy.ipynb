# %% [markdown]
# Multiplicacion de matrices

# %%
import time
import matplotlib.pyplot as pl

n= 25

a=[]
b=[]
t=0
t1=0
for x in range(1,n+1):
    a.append((x))
    c=[[1 for y in range(x)] for y in range(x)]
    d=[[2 for y in range(x)] for y in range(x)]
    e=[[0 for y in range(x)] for y in range(x)]
    for y in range(x):
            for z in range(x):
                    tt=time.clock()
                    for w in range(x):
                        e[y][z]=e[y][z]+(c[y][w]*d[w][z])
                    t=t+time.clock()-tt
                    t1=t1+1
    t=t/t1
    b.append(t)

pl.xlabel("Tamano de la matriz")
pl.ylabel("Tiempo")
pl.title("Tiempo estimado")
pl.plot(a,b)
pl.show()

for x in range(len(b)):
    print "Tiempo para n="+str(x+1)+": " + str(b[x])
# Out:
# Tiempo para n=1: 2.49999999973e-05
# Tiempo para n=2: 1.8399999999e-05
# Tiempo para n=3: 1.35999999996e-05
# Tiempo para n=4: 1.29533333331e-05
# Tiempo para n=5: 6.10824242432e-06
# Tiempo para n=6: 4.59459607048e-06
# Tiempo para n=7: 3.68281854341e-06
# Tiempo para n=8: 3.69942558098e-06
# Tiempo para n=9: 4.55333131787e-06
# Tiempo para n=10: 2.96507358787e-06
# Tiempo para n=11: 2.82206536284e-06
# Tiempo para n=12: 2.64280317745e-06
# Tiempo para n=13: 2.4989533616e-06
# Tiempo para n=14: 2.42512212158e-06
# Tiempo para n=15: 2.31002025979e-06
# Tiempo para n=16: 2.23817514724e-06
# Tiempo para n=17: 2.13962922979e-06
# Tiempo para n=18: 2.07024164496e-06
# Tiempo para n=19: 2.0121741869e-06
# Tiempo para n=20: 1.96690319658e-06
# Tiempo para n=21: 1.90787281885e-06
# Tiempo para n=22: 1.86716939995e-06
# Tiempo para n=23: 1.83068158405e-06
# Tiempo para n=24: 1.81098585339e-06
# Tiempo para n=25: 1.75507891147e-06

# %% [markdown]
# Y en ideone.com :
# Tiempo para n=1: 2e-06
# Tiempo para n=2: 1.19999999999e-06
# Tiempo para n=3: 1.01428571428e-06
# Tiempo para n=4: 9.00476190474e-07
# Tiempo para n=5: 9.25463203464e-07
# Tiempo para n=6: 8.89290804435e-07
# Tiempo para n=7: 9.13494934317e-07
# Tiempo para n=8: 9.01536739874e-07
# Tiempo para n=9: 9.08426444702e-07
# Tiempo para n=10: 9.03658250507e-07
# Tiempo para n=11: 9.16805648715e-07
# Tiempo para n=12: 8.95256624075e-07
# Tiempo para n=13: 9.09518017856e-07
# Tiempo para n=14: 8.89566027604e-07
# Tiempo para n=15: 8.97491585506e-07
# Tiempo para n=16: 9.11696184215e-07
# Tiempo para n=17: 8.87345488058e-07
# Tiempo para n=18: 9.15546394256e-07
# Tiempo para n=19: 8.93083217163e-07
# Tiempo para n=20: 8.96129994152e-07
# Tiempo para n=21: 9.0241501963e-07
# Tiempo para n=22: 8.97734496711e-07
# Tiempo para n=23: 8.915119645e-07
# Tiempo para n=24: 8.87732961625e-07
# Tiempo para n=25: 8.97355245785e-07
