# %% [markdown]
# N-termino de la serie de Fibonacci para n=20

# %%
import time
import matplotlib.pyplot as plt

n=20
tiempo=[]
s=[];
a=0;
b=1;
c=0;
tt=time.clock();
tiempo.append(time.clock()-tt);
s.append(1)
if (n==1):
    print 1
else:
    for x in range(1,n):
        c=a+b;
        a=b;
        b=c;
        t=time.clock()-tt;
        tiempo.append(t)
        s.append(x+1)
    print c
plt.plot(s,tiempo)
plt.title("Tiempos de ejecucion en funcion de n")
plt.xlabel("Numero n")
plt.ylabel("Tiempo")
plt.show()
# Out:
# 6765
